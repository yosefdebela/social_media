# %%
from django.contrib import messages

# %%
for x in dir(messages):
    print(x)
# Out:
# DEBUG
# DEFAULT_LEVELS
# DEFAULT_TAGS
# ERROR
# INFO
# Message
# MessageFailure
# SUCCESS
# WARNING
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __path__
# __spec__
# add_message
# api
# constants
# debug
# error
# get_level
# get_messages
# info
# set_level
# storage
# success
# utils
# warning

# %%
1
