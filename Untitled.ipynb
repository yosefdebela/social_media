# %%
import os

# %%
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "bookmarks.settings")
# Out:
# 'bookmarks.settings'

# %%
import django
django.setup()

# %%
from account import views

# %%
dir(views)
# Out:
# ['HttpResponse',
#  'LoginForm',
#  'Profile',
#  'ProfileEditForm',
#  'UserEditForm',
#  'UserRegistrationForm',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'authenticate',
#  'dashboard',
#  'edit',
#  'edit_done',
#  'home',
#  'login',
#  'login_required',
#  'messages',
#  'redirect',
#  'register',
#  'render',
#  'user_login']

# %%
print(views.messages)
# Out:
# <module 'django.contrib.messages' from '/mnt/000B75A500057336/coding/july6/bookmark/social_env/lib/python3.12/site-packages/django/contrib/messages/__init__.py'>

# %%
print(dir(views.messages))
# Out:
# ['DEBUG', 'DEFAULT_LEVELS', 'DEFAULT_TAGS', 'ERROR', 'INFO', 'Message', 'MessageFailure', 'SUCCESS', 'WARNING', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'add_message', 'api', 'apps', 'constants', 'debug', 'error', 'get_level', 'get_messages', 'info', 'set_level', 'storage', 'success', 'utils', 'warning']

# %%
print(views.messages.get_messages(request))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(views.messages.get_messages(request))
#
# NameError: name 'request' is not defined
